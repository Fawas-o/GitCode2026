# %%
#Absolutely 0 help just me, myself and I
import pandas as pd
import matplotlib.pyplot as plt
#^ for data visualisation ^
from time import sleep

print("---Loading---")

try:
    table = pd.read_csv('lung_cancer.csv')
    print("These are the total number of missing values in this table:")
    print(table.isna().sum())
    sleep(3)
    print(f"---Numbers of rows and columns {table.shape}---")
    sleep(2)

    print(f"---These are the Data types ---\n{table.info}")

    sleep(2)

    print("---A quick preview will be printed soon---")

    time = 0
    while time <= 0:
        try:
            time = int(input("How much rows would you like to get printed: "))
            if time <= 0:
                print("You must input a number above 0")
        except ValueError:
            print("You must input a number over 0")
            time = 0

    for i in range (3,0,-1):
        print(i)
        sleep(1)
    
    print(table.head(time))

    drop = ""
    cln_tbl = table.dropna()

    stats = table['gender'].value_counts()
    race = table['race'].value_counts()
    tmr_lction = table['tumor_location'].value_counts()
    death = table['death01'].value_counts()

    print(stats)
    print()
    print(race)
    print()
    print(tmr_lction)
    print()
    print(death)

    print(f"The oldest person in this data is {table['age_at_initial_pathologic'].max()} \nThe youngest person is {table['age_at_initial_pathologic'].min()}\nthe average age is {round(table['age_at_initial_pathologic'].mean(), 2)}")

    while drop != "Y" and drop != "N":
        drop = input("Would you like to drop any rows with missing data? Y/N ").upper()

    if drop == "Y":
        print(cln_tbl)
    #axis = 0 means rows, axis = 1 means columns
    #printing amount of men and ladies
    table['age_at_initial_pathologic'].plot(kind = 'hist')
    plt.savefig('Age_histogram.png')
    plt.show()

    table['race'].value_counts().plot.pie()
    plt.savefig('race_pie_chart')
    plt.show()

    table['histological_type'].value_counts().plot(kind='barh')#.bar()
    plt.savefig('histological type')
    plt.show()

    table['tumor_tissue_site'].value_counts().plot.bar()
    plt.savefig('tumor tissue site')
    plt.show()

    #box plot - death01 compared to age for boxplot
    table[['age_at_initial_pathologic', 'death01']].boxplot(by = 'death01', column = 'age_at_initial_pathologic')
    plt.savefig('death & age boxplot')
    plt.show()
    


    # print("The ") something with mean etc
except FileNotFoundError:
    print("File couldn't be found")
# Out:
# ---Loading---
# These are the total number of missing values in this table:
# Patient                      0
# TP53Cluster                  0
# EGFRCluster                  0
# CDKN2ACluster                0
# KRAS G12C Cluster            0
# EML4-ALKCluster              0
# histological_type            0
# neoplasm_histologic_grade    0
# tumor_tissue_site            0
# laterality                   0
# tumor_location               0
# gender                       0
# age_at_initial_pathologic    0
# race                         0
# ethnicity                    0
# death01                      0
# dtype: int64
# ---Numbers of rows and columns (1122, 16)---
# ---These are the Data types ---
# <bound method DataFrame.info of      Patient TP53Cluster EGFRCluster CDKN2ACluster KRAS G12C Cluster  \
# 0     LNG001      TP53_2      EGFR_3      CDKN2A_2       KRAS G12C_3
# 1     LNG002      TP53_2      EGFR_3     CDKN2A_1β       KRAS G12C_2
# 2     LNG003      TP53_1      EGFR_5      CDKN2A_2       KRAS G12C_2
# 3     LNG004      TP53_2      EGFR_4      CDKN2A_2       KRAS G12C_3
# 4     LNG005      TP53_5      EGFR_4      CDKN2A_2       KRAS G12C_3
# ...      ...         ...         ...           ...               ...
# 1117  LNG995      TP53_1      EGFR_1     CDKN2A_1α       KRAS G12C_2
# 1118  LNG996      TP53_4      EGFR_5     CDKN2A_1β       KRAS G12C_3
# 1119  LNG997      TP53_4      EGFR_2     CDKN2A_1β       KRAS G12C_2
# 1120  LNG998      TP53_5      EGFR_2     CDKN2A_1α       KRAS G12C_2
# 1121  LNG999      TP53_5      EGFR_2     CDKN2A_1β       KRAS G12C_3
#
#      EML4-ALKCluster          histological_type neoplasm_histologic_grade  \
# 0        EML4-ALK_3a       Large cell carcinoma                        G1
# 1        EML4-ALK_3b       Large cell carcinoma                        G3
# 2        EML4-ALK_3a  Small cell lung carcinoma                        G4
# 3        EML4-ALK_3a             Adenocarcinoma                        G4
# 4        EML4-ALK_3b       Large cell carcinoma                        G1
# ...              ...                        ...                       ...
# 1117     EML4-ALK_3a             Adenocarcinoma                        G4
# 1118      EML4-ALK_1    Squamous cell carcinoma                        G2
# 1119      EML4-ALK_5             Adenocarcinoma                        G4
# 1120     EML4-ALK_3b  Small cell lung carcinoma                        G2
# 1121      EML4-ALK_2  Small cell lung carcinoma                        G4
#
#       tumor_tissue_site laterality tumor_location  gender  \
# 0      Lung, lower lobe      Right        Central  Female
# 1      Lung, lower lobe      Right          Hilar    Male
# 2      Lung, upper lobe      Right     Peripheral    Male
# 3         Main bronchus       Left     Peripheral  Female
# 4      Lung, lower lobe      Right     Peripheral    Male
# ...                 ...        ...            ...     ...
# 1117      Main bronchus      Right        Central    Male
# 1118  Lung, middle lobe       Left          Hilar  Female
# 1119  Lung, middle lobe       Left     Peripheral  Female
# 1120   Lung, upper lobe       Left          Hilar    Male
# 1121   Lung, upper lobe      Right        Central  Female
#
#       age_at_initial_pathologic                       race  \
# 0                            84                      White
# 1                            66                      Asian
# 2                            47                      Asian
# 3                            42  Black or African American
# 4                            68                      Other
# ...                         ...                        ...
# 1117                         49  Black or African American
# 1118                         62                      Asian
# 1119                         76                      Other
# 1120                         60                      Asian
# 1121                         40  Black or African American
#
#                    ethnicity  death01
# 0     Not Hispanic or Latino        0
# 1         Hispanic or Latino        1
# 2     Not Hispanic or Latino        0
# 3     Not Hispanic or Latino        0
# 4     Not Hispanic or Latino        0
# ...                      ...      ...
# 1117      Hispanic or Latino        0
# 1118      Hispanic or Latino        0
# 1119  Not Hispanic or Latino        1
# 1120      Hispanic or Latino        0
# 1121      Hispanic or Latino        0
#
# [1122 rows x 16 columns]>
# ---A quick preview will be printed soon---
# 3
# 2
# 1
#   Patient TP53Cluster EGFRCluster CDKN2ACluster KRAS G12C Cluster  \
# 0  LNG001      TP53_2      EGFR_3      CDKN2A_2       KRAS G12C_3
# 1  LNG002      TP53_2      EGFR_3     CDKN2A_1β       KRAS G12C_2
# 2  LNG003      TP53_1      EGFR_5      CDKN2A_2       KRAS G12C_2
# 3  LNG004      TP53_2      EGFR_4      CDKN2A_2       KRAS G12C_3
# 4  LNG005      TP53_5      EGFR_4      CDKN2A_2       KRAS G12C_3
# 5  LNG006      TP53_3      EGFR_2     CDKN2A_1α       KRAS G12C_2
# 6  LNG007      TP53_2      EGFR_5     CDKN2A_1β       KRAS G12C_2
#
#   EML4-ALKCluster          histological_type neoplasm_histologic_grade  \
# 0     EML4-ALK_3a       Large cell carcinoma                        G1
# 1     EML4-ALK_3b       Large cell carcinoma                        G3
# 2     EML4-ALK_3a  Small cell lung carcinoma                        G4
# 3     EML4-ALK_3a             Adenocarcinoma                        G4
# 4     EML4-ALK_3b       Large cell carcinoma                        G1
# 5      EML4-ALK_2       Large cell carcinoma                        G4
# 6      EML4-ALK_2             Adenocarcinoma                        G1
#
#   tumor_tissue_site laterality tumor_location  gender  \
# 0  Lung, lower lobe      Right        Central  Female
# 1  Lung, lower lobe      Right          Hilar    Male
# 2  Lung, upper lobe      Right     Peripheral    Male
# 3     Main bronchus       Left     Peripheral  Female
# 4  Lung, lower lobe      Right     Peripheral    Male
# 5  Lung, lower lobe      Right     Peripheral    Male
# 6     Main bronchus       Left        Central    Male
#
#    age_at_initial_pathologic                       race  \
# 0                         84                      White
# 1                         66                      Asian
# 2                         47                      Asian
# 3                         42  Black or African American
# 4                         68                      Other
# 5                         66  Black or African American
# 6                         70                      Asian
#
#                 ethnicity  death01
# 0  Not Hispanic or Latino        0
# 1      Hispanic or Latino        1
# 2  Not Hispanic or Latino        0
# 3  Not Hispanic or Latino        0
# 4  Not Hispanic or Latino        0
# 5  Not Hispanic or Latino        0
# 6  Not Hispanic or Latino        1
# gender
# Male      564
# Female    558
# Name: count, dtype: int64
#
# race
# Asian                        295
# White                        281
# Black or African American    276
# Other                        270
# Name: count, dtype: int64
#
# tumor_location
# Hilar         395
# Peripheral    379
# Central       348
# Name: count, dtype: int64
#
# death01
# 0    568
# 1    554
# Name: count, dtype: int64
# The oldest person in this data is 85
# The youngest person is 35
# the average age is 60.28
#      Patient TP53Cluster EGFRCluster CDKN2ACluster KRAS G12C Cluster  \
# 0     LNG001      TP53_2      EGFR_3      CDKN2A_2       KRAS G12C_3
# 1     LNG002      TP53_2      EGFR_3     CDKN2A_1β       KRAS G12C_2
# 2     LNG003      TP53_1      EGFR_5      CDKN2A_2       KRAS G12C_2
# 3     LNG004      TP53_2      EGFR_4      CDKN2A_2       KRAS G12C_3
# 4     LNG005      TP53_5      EGFR_4      CDKN2A_2       KRAS G12C_3
# ...      ...         ...         ...           ...               ...
# 1117  LNG995      TP53_1      EGFR_1     CDKN2A_1α       KRAS G12C_2
# 1118  LNG996      TP53_4      EGFR_5     CDKN2A_1β       KRAS G12C_3
# 1119  LNG997      TP53_4      EGFR_2     CDKN2A_1β       KRAS G12C_2
# 1120  LNG998      TP53_5      EGFR_2     CDKN2A_1α       KRAS G12C_2
# 1121  LNG999      TP53_5      EGFR_2     CDKN2A_1β       KRAS G12C_3
#
#      EML4-ALKCluster          histological_type neoplasm_histologic_grade  \
# 0        EML4-ALK_3a       Large cell carcinoma                        G1
# 1        EML4-ALK_3b       Large cell carcinoma                        G3
# 2        EML4-ALK_3a  Small cell lung carcinoma                        G4
# 3        EML4-ALK_3a             Adenocarcinoma                        G4
# 4        EML4-ALK_3b       Large cell carcinoma                        G1
# ...              ...                        ...                       ...
# 1117     EML4-ALK_3a             Adenocarcinoma                        G4
# 1118      EML4-ALK_1    Squamous cell carcinoma                        G2
# 1119      EML4-ALK_5             Adenocarcinoma                        G4
# 1120     EML4-ALK_3b  Small cell lung carcinoma                        G2
# 1121      EML4-ALK_2  Small cell lung carcinoma                        G4
#
#       tumor_tissue_site laterality tumor_location  gender  \
# 0      Lung, lower lobe      Right        Central  Female
# 1      Lung, lower lobe      Right          Hilar    Male
# 2      Lung, upper lobe      Right     Peripheral    Male
# 3         Main bronchus       Left     Peripheral  Female
# 4      Lung, lower lobe      Right     Peripheral    Male
# ...                 ...        ...            ...     ...
# 1117      Main bronchus      Right        Central    Male
# 1118  Lung, middle lobe       Left          Hilar  Female
# 1119  Lung, middle lobe       Left     Peripheral  Female
# 1120   Lung, upper lobe       Left          Hilar    Male
# 1121   Lung, upper lobe      Right        Central  Female
#
#       age_at_initial_pathologic                       race  \
# 0                            84                      White
# 1                            66                      Asian
# 2                            47                      Asian
# 3                            42  Black or African American
# 4                            68                      Other
# ...                         ...                        ...
# 1117                         49  Black or African American
# 1118                         62                      Asian
# 1119                         76                      Other
# 1120                         60                      Asian
# 1121                         40  Black or African American
#
#                    ethnicity  death01
# 0     Not Hispanic or Latino        0
# 1         Hispanic or Latino        1
# 2     Not Hispanic or Latino        0
# 3     Not Hispanic or Latino        0
# 4     Not Hispanic or Latino        0
# ...                      ...      ...
# 1117      Hispanic or Latino        0
# 1118      Hispanic or Latino        0
# 1119  Not Hispanic or Latino        1
# 1120      Hispanic or Latino        0
# 1121      Hispanic or Latino        0
#
# [1122 rows x 16 columns]

# %%
table['race'].value_counts().plot.pie()
plt.savefig('race_pie_chart')
plt.show()

# %%
table['histological_type'].value_counts().plot(kind='barh')#.bar()
plt.savefig('histological type')
plt.show()

# %%
table['tumor_tissue_site'].value_counts().plot.bar()
plt.savefig('tumor tissue site')
plt.show()

# %%
#box plot - death01 compared to age for boxplot
table[['age_at_initial_pathologic', 'death01']].boxplot(by = 'death01', column = 'age_at_initial_pathologic')
plt.savefig('death & age boxplot')
plt.show()

# %%
 #need to fix should be only two bars
table[['gender', 'death01']].value_counts().plot.bar()
plt.savefig('gender against death')
plt.show()
